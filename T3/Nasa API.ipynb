# %%
import requests,json
from bs4 import BeautifulSoup
api="qRPzYldoUer41Y6cB1URNAPLqjRfVfkY32Krtsh1"
request_url=f'https://api.nasa.gov/planetary/apod'
response=requests.get(request_url,params={'api_key':'hrdQTL271Cv3zveylzpMSsYQ55vtpakdjhM17XC5','count':10})
d=response.json()

# %%
date=[]
url=[]
title=[]
for i in d:    
    date.append(i.get("date"))
    url.append(i["url"])
    title.append(i["title"])
import pandas as pd
df=pd.DataFrame({"Date" : date})
df
# Out:
#          Date
# 0  2004-03-22
# 1  2016-02-08
# 2  2015-11-11
# 3  2001-12-16
# 4  2024-12-30
# 5  2002-04-21
# 6  2018-11-15
# 7  2015-01-16
# 8  2006-02-21
# 9  2014-05-21
